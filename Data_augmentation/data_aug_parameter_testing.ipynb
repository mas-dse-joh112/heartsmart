# %%
from scipy.ndimage.interpolation import map_coordinates, affine_transform
from scipy.ndimage.filters import gaussian_filter
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import os
import matplotlib.pyplot as plt
from skimage import io
# %matplotlib inline

# %%
#Original image
image='/Disha/DSE/dsingla/capstone/data/patient078_slice1_frame1.nii.npy'
img=np.load(image)
plt.imshow(img, cmap="bone")

# %% [markdown]
# ### Through keras

# %%
datagen = ImageDataGenerator(
          rotation_range=40,
        #width_shift_range=0.5,
        #height_shift_range=0.2,
        #shear_range=0.4,
        #zoom_range=0.15,#0.1, #before 0.3
        horizontal_flip=True,
        #fill_mode='nearest'
       )

# %%
#converting to 3d; using Ehab's code
"""ds = img
finalArray = np.zeros((img.shape[0], img.shape[1], 3))
for index in range(3):
    finalArray[:, :, index] = ds"""

# %%
print(img.shape)
img = img_to_array(img)
img.shape
# Out:
# (295, 350, 1)
# (295, 350, 1)

# %%
x=img
x = x.reshape((1,) + x.shape)
x.shape
# Out:
# (1, 295, 350, 1)

# %%
i = 0
for batch in datagen.flow(x, batch_size=1, save_to_dir='/Disha/DSE/dsingla/capstone/preview/shear//', save_prefix='test_pt4', save_format='jpeg'):   
    i += 1
    if i > 10:
        break
