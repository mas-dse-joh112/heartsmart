# %%
import dicom
import numpy as np
import os
import glob
import re

# %%
#ACDCimgpath='/opt/data/acdc/niftidata/'
SCDimgpathT = '/opt/data/sunnybrook/challenge_training/'
SCDimgpathV = '/opt/data/sunnybrook/challenge_validation/'
SCDlblpath = '/opt/output/sunnybrook/norm/1/3/labels/'

# %%
results = []
for root, _, files in os.walk(SCDlblpath):
    rootnode = root.split("/")
    #label = rootnode[-2]
    filename = rootnode[-1]
    #patient_path = SCDlblpath + filename + '/'
    
    if os.path.isdir(SCDimgpathT + filename + '/') is True:
        origimgpath = SCDimgpathT + filename + '/'
        patient_path = SCDlblpath + filename + '/'
        results.append([filename, patientVolume(patient_path)])
    
    elif os.path.isdir(SCDimgpathV + filename + '/') is True:
        origimgpath = SCDimgpathV + filename + '/'
        patient_path = SCDlblpath + filename + '/'
        results.append([filename, patientVolume(patient_path)])
    
    else:
        #print (SCDimgpathT + filename + '/')
        print('Challenge_Online Directory')
    #print (rootnode, patient_path)
# Out:
# /opt/output/sunnybrook/norm/1/3/labels//
# []
# []
# Challenge_Online Directory
# /opt/output/sunnybrook/norm/1/3/labels/SC-N-6/
# A slice has one frame
# [[-48.219954177833316, ['0039']]]
# []
# /opt/output/sunnybrook/norm/1/3/labels/SC-HYP-7/
# []
# []
# /opt/output/sunnybrook/norm/1/3/labels/SC-HF-NI-4/
# []
# []
# /opt/output/sunnybrook/norm/1/3/labels/SC-HF-I-7/
# []
# []
# /opt/output/sunnybrook/norm/1/3/labels/SC-HF-NI-11/
# []
# []
# /opt/output/sunnybrook/norm/1/3/labels/SC-N-40/
# A slice has one frame
# [[-34.858566013027556, ['0100']]]
# []
# /opt/output/sunnybrook/norm/1/3/labels/SC-HF-NI-3/
# []
# []
# /opt/output/sunnybrook/norm/1/3/labels/SC-HYP-38/
# A slice has one frame
# A slice has one frame
# [[-165.2536460995089, ['0218']], [-75.25366237334399, ['0038']]]
# []
# /opt/output/sunnybrook/norm/1/3/labels/SC-HF-NI-34/
# []
# []
# /opt/output/sunnybrook/norm/1/3/labels/SC-N-5/
# A slice has one frame
# [[-106.34878257468603, ['0160']]]
# []
# ...

# %%
one=set(['SC-N-6', 'SC-N-40', 'SC-HYP-38', 'SC-N-5', 'SC-N-2', 'SC-HYP-3', 'SC-HF-NI-33', 'SC-HYP-1', 'SC-HF-NI-31', 'SC-N-7', 
     'SC-HYP-6','SC-N-3','SC-HYP-8', 'SC-HYP-37'])
full_results=[]
for i in range(len(results)):
    if results[i][0] not in one:
            full_results.append(results[i])

# %%
full_results
# Out:
# [['', (0.0, 0.0)],
#  ['SC-HYP-7', (78.98029382727862, 163.72115934375643)],
#  ['SC-HF-NI-4', (291.09905224666255, 334.01436273426356)],
#  ['SC-HF-I-7', (155.43252481471586, 192.99230820770154)],
#  ['SC-HF-NI-11', (372.8110224176309, 413.716257327249)],
#  ['SC-HF-NI-3', (335.56834850518, 379.2844984134069)],
#  ['SC-HF-NI-34', (204.28975316103663, 274.5748474254846)],
#  ['SC-HF-I-4', (262.23688971466555, 307.68100972975)],
#  ['SC-HF-NI-7', (329.6471792532549, 361.39522134475595)],
#  ['SC-HF-I-1', (210.5799791004978, 256.04029673762466)],
#  ['SC-HF-I-6', (238.7696031570189, 291.43015339585685)],
#  ['SC-HF-NI-36', (341.27499512947105, 378.5352284868813)],
#  ['SC-HF-I-2', (260.6623641176811, 319.22700862320784)],
#  ['SC-HF-I-8', (284.5854221079655, 331.6418629217886)],
#  ['SC-HF-I-5', (193.971227418228, 255.25467427736538)],
#  ['SC-HF-I-40', (106.61278964429454, 151.48418274901033)],
#  ['SC-HYP-40', (72.29344723448415, 111.06135967300912)]]

# %%
TESV, FESV, TEDV, FEDV = checkVolumes(full_results)
# Out:
# Normal Error:
# 0 0
# HYP Error:
# 16.053741061762764 0
# HF-I Error:
# 0 98.64178824773995
# HF-NI Error:
# 597.3005975521994 163.81249305887428
# Total ESV Error:
# 613.3543386139622
# Total EDV Error:
# 262.45428130661423

# %%
TESV, FESV, TEDV, FEDV=checkVolumes(results)
# Out:
# Normal Error:
# 49.72163877397868 10.835922322446478
# HYP Error:
# 79.85917474292286 33.4345663188399
# HF-I Error:
# 0 98.64178824773995
# HF-NI Error:
# 609.7366746472189 209.15857015389386
# Total ESV Error:
# 739.3174881641205
# Total EDV Error:
# 352.07084704292015

# %%
len(TESV) , len(FESV) , len(FEDV), len(TEDV)
# Out:
# (17, 13, 10, 20)

# %%
FEDV
# Out:
# [['SC-N-6', (35.9499710381077, 78.36992326395857)],
#  ['SC-HF-I-7', (104.01960013021684, 141.5793835232025)],
#  ['SC-N-40', (39.09974828169934, 66.39969959132132)],
#  ['SC-N-5', (27.768304131009682, 71.36478026126935)],
#  ['SC-HYP-8', (87.77545650468306, 207.9811132322272)],
#  ['SC-HF-I-40', (71.1912246293624, 116.06261773407817)]]

# %%
def normalCheck(results):
  
    NESV = [43.10, 14.74]
    minESV = NESV[0] - NESV[1]
    maxESV = NESV[0] + NESV[1]
    NEDV = [115.69, 36.89]
    minEDV = NEDV[0] - NEDV[1]
    maxEDV = NEDV[0] + NEDV[1]
    nsError = 0
    ndError = 0
    
    for i in range(len(results)):
        
        if (minESV <= results[i][1][0]) and (results[i][1][0] <= maxESV):

# %%
def checkVolumes(results):

    NESV = [43.10, 14.74]
    NEDV = [115.69, 36.89]
    nsError = 0
    ndError = 0
    
    HYPESV = [43.11,24.50 ]
    HYPEDV = [114.39, 50.46]

    hypsError = 0
    hypdError = 0
    
    HFIESV = [174.34,90.64]
    HFIEDV = [244.92, 86.02]
    hfisError = 0
    hfidError = 0
    
    HFNIESV = [158.28, 56.34]
    HFNIEDV = [244.92, 63.21]
    hfnisError = 0
    hfnidError = 0
    
    TESV = []
    FESV = []
    TEDV = []
    FEDV = []
    
    for i in range(len(results)):
        if ('-N-') in results[i][0]:
            if results[i][1][0] >= (43.10 -14.74) and results[i][1][0] <= (43.10 + 14.74):
            #if ((NESV[0]-NESV[1]) <= results[i][1][0]) and (results [i][0] <= (NESV[0]+NESV[1])):
                #print (results[i], 'ESV True')
                TESV.append(results[i])
            else:
                #print (results[i], 'ESV False')
                FESV.append(results[i])
                tmp1 = min(abs(results[i][1][0] - (NESV[0]-NESV[1])), abs(results[i][1][0] - (NESV[0]+NESV[1])))
                nsError = nsError + tmp1
            if results[i][1][1] >= (115.69 -36.89) and results[i][1][1] <= (115.69 + 36.89):
            #if ((NEDV[0]-NEDV[1]) <= results[i][1][0]) and (results[i][0] <= (NEDV[0]+NEDV[1])):
                #print (results[i], 'EDV True')
                TEDV.append(results[i])
               
            else:
                #print (results[i], 'EDV False')
                FEDV.append(results[i])
                tmp1 = min(abs(results[i][1][0] - (NEDV[0]-NEDV[1])), abs(results[i][1][0] - (NEDV[0]+NEDV[1])))
                ndError = ndError + tmp1
        if ('-HYP-') in results[i][0]:
            if results[i][1][0] >= (43.11 -24.50) and results[i][1][0] <= (43.11 + 24.50):
            #if ((HYPESV[0]-HYPESV[1]) <= results[i][1][0]) and (results[i][0] <= (HYPESV[0]+HYPESV[1])): 
                #print (results[i], 'ESV True')
                TESV.append(results[i])
            else:
                #print (results[i], 'ESV False')
                FESV.append(results[i])
                tmp1 = min(abs(results[i][1][0] - (HYPESV[0]-HYPESV[1])), abs(results[i][1][0] - (HYPESV[0]+HYPESV[1])))
                hypsError = hypsError + tmp1
            if results[i][1][1] >= (114.39 -50.46) and results[i][1][1] <= (114.39 + 50.46):
            #if ((HYPEDV[0]-HYPEDV[1]) <= results[i][1][0]) and (results[i][0] <= (HYPEDV[0]+HYPEDV[1])):
                #print (results[i], 'EDV True')
                TEDV.append(results[i])
                
            else:
                #print (results[i], 'EDV False')
                FEDV.append(results[i])
                tmp1 = min(abs(results[i][1][0] - (HYPEDV[0]-HYPEDV[1])), abs(results[i][1][0] - (HYPEDV[0]+HYPEDV[1])))
                hypdError = hypdError + tmp1
        if ('-HF-I') in results[i][0]:
            if results[i][1][0] >= (174.34  -90.64) or results[i][1][0] <= (174.34  + 90.64):
            #if ((HFIESV[0]-HFIESV[1]) <= results[i][1][0]) and (results[i][0] <= (HFIESV[0]+HFIESV[1])):
                #print (results[i], 'ESV True')
                TESV.append(results[i])
            else:
                #print (results[i], 'ESV False')
                FESV.append(results[i])
                tmp1 = min(abs(results[i][1][0] - (HFIESV[0]-HFIESV[1])), abs(results[i][1][0] - (HFIESV[0]+HFIESV[1])))
                hfsiError = hfisError + tmp1
            if results[i][1][1] >= (244.92 -86.02) and results[i][1][1] <= (244.92 + 86.02):
            #if ((HFIEDV[0]-HFIEDV[1]) <= results[i][1][0]) and (results[i][0] <= (HFIEDV[0]+HFIEDV[1])):
                #print (results[i], 'EDV True')
                TEDV.append(results[i])
            else:
                #print (results[i], 'EDV False')
                FEDV.append(results[i])
                tmp1 = min(abs(results[i][1][0] - (HFIEDV[0]-HFIEDV[1])), abs(results[i][1][0] - (HFIEDV[0]+HFIEDV[1])))
                hfidError = hfidError + tmp1
        if ('-HF-NI') in results[i][0]:
            if results[i][1][0] >= (158.28  -56.34) and results[i][1][0] <= (158.28  + 56.34):
            #if ((HFNIESV[0]-HFNIESV[1]) <= results[i][1][0]) and (results[i][0] <= (HFNIESV[0]+HFNIESV[1])):
                #print (results[i], 'ESV True')
                TESV.append(results[i])
            else:
                #print (results[i], 'ESV False')
                FESV.append(results[i])
                tmp1 = min(abs(results[i][1][0] - (HFNIESV[0]-HFNIESV[1])), abs(results[i][1][0] - (HFNIESV[0]+HFNIESV[1])))
                hfnisError = hfnisError + tmp1
            if results[i][1][1] >= (233.67 -63.21) and results[i][1][1] <= (233.67 + 63.21):
            #if ((HFNIEDV[0]-HFNIEEDV[1]) <= results[i][1][0]) and (results[i][0] <= (HFNIEDV[0]+HFNIEDV[1])):
                #print (results[i], 'EDV True')
                TEDV.append(results[i])
            else:
                #print (results[i], 'EDV False')
                FEDV.append(results[i])
                tmp1 = min(abs(results[i][1][0] - (HFNIEDV[0]-HFNIEDV[1])), abs(results[i][1][0] - (HFNIEDV[0]+HFNIEDV[1])))
                hfnidError = hfnidError + tmp1
    
    print ('Normal Error: ') 
    print (nsError, ndError)
    print ('HYP Error: ') 
    print (hypsError, hypdError)
    print ('HF-I Error: ') 
    print (hfisError, hfidError)
    print ('HF-NI Error: ') 
    print (hfnisError, hfnidError)
    
    print ('Total ESV Error: ')
    print (nsError + hypsError + hfisError + hfnisError)
    print ('Total EDV Error: ')
    print (ndError + hypdError + hfidError + hfnidError)
    return (TESV, FESV, TEDV, FEDV)

# %%
def patientVolume(patient_path):
    for root,_, files in os.walk(patient_path):
        
            norm = None
            #norm = 1
            slicedict={}
            print (patient_path)
        
            for i in files:
                #print (i)
                filenode = i.strip('.dcm.label.npy')
                filenode = re.split('-',filenode)
                #print (filenode)
                patient = filenode[1]
                #slicenum = 
                #frame = int(filenode[2])
                lblpath = root +'/'+ i
            
                imgpath = getDICOM(origimgpath, patient, filenode[2])

                img = dicom.read_file(imgpath)
            
                if norm is not None:
                    ps = img.PixelSpacing[0]
                else:
                    ps = 1
            
                thickness = img.SliceThickness
                gap = img.SpacingBetweenSlices
                sliceLocation = slicelocation(img)
            
                lbl = np.load(lblpath)
            
                frac = getfrac(lbl)
                #area = frac * (ps * len(lbl))
                area = getarea(lbl, frac, ps)
                #area = frac * ((sum(i == 1 for i in img.flatten())) * len(lbl))
                volume = thickness * area

                if sliceLocation in slicedict:
                    slicedict[sliceLocation].update({filenode[2]:
                                                {'fraction': frac,
                                                 'Area': area, 
                                                 'Volume': volume}})
                else:
                    slicedict[sliceLocation] = {filenode[2]:
                                        {'fraction': frac,
                                        'Area': area, 
                                        'Volume': volume}}
            
            ESF, ESV, EDF, EDV = getVolumes(slicedict)
            return (ESV, EDV)

# %%
def getDICOM(path, patient, img):
    imgpath = path + 'IM-' +patient +'-'+ img + '.dcm'
    return imgpath

# %%
def getfrac(img):
    frac = (sum(i == 1 for i in img.flatten()))/float(len(img.flatten()))
    return frac

# %%
def getarea(img, frac, ps): 
    #area = frac * ((sum(i ==1 for i in img.flatten())) * len(img))
    #area = frac * (ps * len(img))
    area = frac * (ps*len(img))**2
    return area

# %%
def slicelocation(img):
    sl= np.dot(img.ImagePositionPatient,
                   np.cross(img.ImageOrientationPatient[:3],img.ImageOrientationPatient[3:]))
    return sl

# %%
def getVolumes(slicedict):
    ESF = []
    ESVlist = []
    EDF = []
    EDVlist = []
    ESArea = []
    EDArea = []
    SL = []
    moreFrame = []
    oneFrame = []
    #print (slicedict.keys())

    for key in sorted(slicedict):
        #print (key)
        frames = list(slicedict[key].keys())
        #print (frames)
        if len(frames) > 2:
            print ('A slice has more than two frames')
            moreFrame.append([key, frames])
        if len(frames) < 2:
            print ('A slice has one frame')
            oneFrame.append([key, frames])
            
        if len(frames) == 2:
            SL.append(key)
            for i in range(len(frames)-1):
            #print (slicedict[key][frames[i]]['fraction'], slicedict[key][frames[i+1]]['fraction'] )
                if slicedict[key][frames[i]]['fraction'] < slicedict[key][frames[i+1]]['fraction']:
                    ESF.append(frames[i])
                    EDF.append(frames[i+1])
                    ESVlist.append(slicedict[key][frames[i]]['Volume'])
                    EDVlist.append(slicedict[key][frames[i+1]]['Volume'])
                    ESArea.append(slicedict[key][frames[i]]['Area'])
                    EDArea.append(slicedict[key][frames[i+1]]['Area'])
                
                else:
                    ESF.append(frames[i+1])
                    ESVlist.append(slicedict[key][frames[i+1]]['Volume'])
                    ESArea.append(slicedict[key][frames[i+1]]['Area'])
                    EDF.append(frames [i])
                    EDVlist.append(slicedict[key][frames[i]]['Volume'])
                    EDArea.append(slicedict[key][frames[i]]['Area'])
    #print (ESF, EDF)

        #ESV = sum(ESVlist)
        #EDV = sum(EDVlist)
        #SL = list(slicedict.keys())
        #SL.sort()
    ESV = 0
    EDV = 0
    #print (len(SL), len(ESVlist), len(EDVlist))
    for i in range(len(SL)-1):
        #print (i)
        ESV = ESV + (ESArea[i] + ESArea[i+1]) * (abs(SL[i+1]-SL[i])/2)
        EDV = EDV + (EDArea[i] + EDArea[i+1]) * (abs(SL[i+1]-SL[i])/2)
        
        #ESV = ESV + (ESArea[i] + ESArea[i+1] + np.sqrt(ESArea[i]*ESArea[i+1])) * (abs(SL[i+1]-SL[i])/2)
        #EDV = EDV + (EDArea[i] + EDArea[i+1] + np.sqrt(ESArea[i]*ESArea[i+1])) * (abs(SL[i+1]-SL[i])/2)
        
    ESV = ESV / 1000
    EDV = EDV / 1000
    
    print (oneFrame)
    print (moreFrame)
    return ESF, ESV, EDF, EDV
