# %%
import re, sys, math
import glob
import random
import json
import os 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import log_loss
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
from collections import OrderedDict
import pandas as pd
from helper_utilities import *
from helper_plotutilities import *

# %matplotlib inline

# %%
keys = ["samples", "logloss", "weighted_logloss","accuracy", "weighted_accuracy", "precision","recall", "f1_score", "true_positive", \
       "false_positive","true_negative","false_negative", "zero_contour_labels", "zero_contour_pred", \
       "missed_pred_lt_05", "missed_pred_gt_25", "missed_pred_gt_50", "missed_pred_eq_100"]

# %%
explist256 = glob.glob("/masvol/heartsmart/unet_model/baseline/results/roi/combined_1_3_0_256*_learning_history.json")

# %%
# reg for regular

# %% [markdown]
# ## all learning history of 256

# %%
for results_file in explist256 :
    history_file = results_file
    #history_file = RESULTS_PATH + results_file + '_learning_history.json'
    print ('='*30)
    print ('='*30)
    print ("Learning history of :" + results_file)
    print ('-'*30)
    
    plot_learning_history(history_file)
# Out:
# ==============================
# ==============================
# Learning history of :/masvol/heartsmart/unet_model/baseline/results/roi/combined_1_3_0_256_roi_aug_drop_dice_learning_history.json
# ------------------------------
# ------------------------------
# Model Parameters
# tr_size  :  9748
# tr_nGPUs  :  4
# tr_loss_fn  :  dice_loss
# tr_dropout  :  True
# tr_model_name  :  combined_1_3_0_256_roi_aug_drop_dice
# tr_epoch  :  80
# tr_lrrate  :  2e-05
# tr_optimizer  :  Adam
# tr_batchsize  :  32
# ------------------------------
# Evaluation on Test set
# eval_binary_accuracy  :  0.9741946750217014
# eval_loss  :  0.9998229106267293
# eval_dice_coeff  :  0.000177092732715041
# ------------------------------
# Values at first and last epoch
# ------------------------------
# loss  :  0.5471856175217453 , 0.028250768188330784
# binary_accuracy  :  0.8226763913649172 , 0.9974913184659302
# val_loss  :  0.36262636548433547 , 0.05343071338457939
# val_binary_accuracy  :  0.9842043209687258 , 0.9958688116684938
# dice_coeff  :  0.452814383074454 , 0.9717492318116692
# val_dice_coeff  :  0.6373736349741618 , 0.9465692866154206
# ------------------------------
# ------------------------------
# ==============================
# ==============================
# Learning history of :/masvol/heartsmart/unet_model/baseline/results/roi/combined_1_3_0_256_roi_aug_dice_learning_history.json
# ------------------------------
# ------------------------------
# Model Parameters
# tr_size  :  9748
# tr_nGPUs  :  4
# tr_loss_fn  :  dice_loss
# tr_dropout  :  False
# tr_model_name  :  combined_1_3_0_256_roi_aug_dice
# tr_epoch  :  80
# tr_optimizer  :  Adam
# tr_lrrate  :  2e-05
# tr_batchsize  :  32
# ------------------------------
# Evaluation on Test set
# eval_binary_accuracy  :  0.9741999873408564
# eval_loss  :  0.9995030111736721
# eval_dice_coeff  :  0.0004969941238717486
# ------------------------------
# Values at first and last epoch
# ------------------------------
# val_dice_coeff  :  0.6495744925890213 , 0.9491593939830095
# binary_accuracy  :  0.8719845048034152 , 0.9976367798485063
# val_loss  :  0.35042550741097866 , 0.05084060601699047
# val_binary_accuracy  :  0.9774294963249793 , 0.9959855532646179
# dice_coeff  :  0.4431132716104048 , 0.9752181048544898
# loss  :  0.5568867292609634 , 0.024781895145510185
# ------------------------------
# ------------------------------
# ==============================
# ==============================
# Learning history of :/masvol/heartsmart/unet_model/baseline/results/roi/combined_1_3_0_256_roi_drop_dice_learning_history.json
# ------------------------------
# ------------------------------
# Model Parameters
# tr_size  :  2437
# tr_nGPUs  :  4
# tr_loss_fn  :  dice_loss
# tr_dropout  :  True
# tr_model_name  :  combined_1_3_0_256_roi_drop_dice
# tr_epoch  :  80
# tr_optimizer  :  Adam
# tr_lrrate  :  2e-05
# tr_batchsize  :  32
# ------------------------------
# Evaluation on Test set
# eval_binary_accuracy  :  0.9743118286132812
# eval_loss  :  0.992857504774023
# eval_dice_coeff  :  0.0071424976705909814
# ------------------------------
# Values at first and last epoch
# ------------------------------
# loss  :  0.9289438538884065 , 0.03165415885656109
# binary_accuracy  :  0.37415018914723286 , 0.9985771196019411
# val_loss  :  0.8626592892115234 , 0.07379593907809648
# val_binary_accuracy  :  0.9427353280489562 , 0.9954887452672739
# dice_coeff  :  0.07105614679586955 , 0.9683458410880087
# val_dice_coeff  :  0.13734070639141271 , 0.9262040609219035
# ------------------------------
# ------------------------------
# ==============================
# ==============================
# Learning history of :/masvol/heartsmart/unet_model/baseline/results/roi/combined_1_3_0_256_roi_dice_learning_history.json
# ------------------------------
# ------------------------------
# Model Parameters
# tr_size  :  2437
# tr_loss_fn  :  dice_loss
# tr_nGPUs  :  4
# tr_dropout  :  False
# tr_model_name  :  combined_1_3_0_256_roi_dice
# tr_epoch  :  80
# tr_optimizer  :  Adam
# tr_lrrate  :  2e-05
# tr_batchsize  :  32
# ------------------------------
# Evaluation on Test set
# eval_binary_accuracy  :  0.9743584526909722
# eval_loss  :  0.9911639460810908
# eval_dice_coeff  :  0.008836058302053803
# ------------------------------
# Values at first and last epoch
# ------------------------------
# loss  :  0.8989513553736331 , 0.03118211263384557
# binary_accuracy  :  0.58356016699995 , 0.9986026814621249
# val_loss  :  0.720882909219773 , 0.07322290295460185
# val_binary_accuracy  :  0.9343040653916656 , 0.9955735753794186
# dice_coeff  :  0.10104864097944341 , 0.9688178873661544
# val_dice_coeff  :  0.27911709664297885 , 0.9267770970453981
# ------------------------------
# ------------------------------
# ==============================
# ==============================
# Learning history of :/masvol/heartsmart/unet_model/baseline/results/roi/combined_1_3_0_256_roi_not_norm_drop_dice_learning_history.json
# ------------------------------
# ------------------------------
# Model Parameters
# tr_size  :  2437
# tr_nGPUs  :  4
# tr_loss_fn  :  dice_loss
# tr_dropout  :  True
# tr_model_name  :  combined_1_3_0_256_roi_not_norm_drop_dice
# tr_epoch  :  80
# tr_optimizer  :  Adam
# tr_lrrate  :  2e-05
# tr_batchsize  :  32
# ------------------------------
# Evaluation on Test set
# eval_binary_accuracy  :  0.975025713885272
# eval_loss  :  0.9545511484146119
# eval_dice_coeff  :  0.045448853714710656
# ------------------------------
# Values at first and last epoch
# ------------------------------
# loss  :  0.9290299853219198 , 0.031170725369450373
# binary_accuracy  :  0.3700317960631976 , 0.998598172121503
# val_loss  :  0.8604943459151221 , 0.07530330243657847
# val_binary_accuracy  :  0.9354436592977555 , 0.9953703958480085
# dice_coeff  :  0.07097001185305245 , 0.9688292745751195
# val_dice_coeff  :  0.13950565139778326 , 0.9246966975634215
# ------------------------------
# ------------------------------
# ==============================
# ==============================
# Learning history of :/masvol/heartsmart/unet_model/baseline/results/roi/combined_1_3_0_256_roi_not_norm_dice_learning_history.json
# ------------------------------
# ------------------------------
# Model Parameters
# tr_lrrate  :  2e-05
# tr_size  :  2437
# tr_loss_fn  :  dice_loss
# tr_dropout  :  False
# tr_model_name  :  combined_1_3_0_256_roi_not_norm_dice
# tr_epoch  :  80
# tr_nGPUs  :  4
# tr_optimizer  :  Adam
# tr_batchsize  :  32
# ------------------------------
# Evaluation on Test set
# eval_binary_accuracy  :  0.9742325959382234
# eval_loss  :  0.99779416013647
# eval_dice_coeff  :  0.002205844147182587
# ------------------------------
# Values at first and last epoch
# ------------------------------
# loss  :  0.8101989205920923 , 0.02307494586403398
# binary_accuracy  :  0.921266989747092 , 0.9989632475431177
# val_loss  :  0.5366081908100941 , 0.07931520802075745
# val_binary_accuracy  :  0.9481602340448098 , 0.995276466744845
# dice_coeff  :  0.18980108006542434 , 0.976925054135966
# val_dice_coeff  :  0.4633918111441565 , 0.9206847919792426
# ------------------------------
# ------------------------------

# %% [markdown]
# ## all learning history of 176

# %%
# explist176 = glob.glob("/masvol/heartsmart/unet_model/data/combined_1_1_176*32B_learning_history.json")

# %%
for results_file in explist176 :
    history_file = results_file
    print ('='*30)
    print ('='*30)
    print ("Learning history of :" + results_file)
    print ('-'*30)
    
    plot_learning_history(history_file)

# %% [markdown]
# ## 256 AUG

# %%
weights_file = "/masvol/heartsmart/unet_model/baseline/results/roi/combined_1_3_0_256_roi_aug_dice.hdf5"
history_file = '/masvol/heartsmart/unet_model/baseline/results/roi/combined_1_3_0_256_roi_aug_dice_learning_history.json'
image_file = "/masvol/heartsmart/unet_model/baseline/data/combined_1_3_0_256_test_images_ROI_norm.npy"
label_file = "/masvol/heartsmart/unet_model/baseline/data/combined_1_3_0_256_test_labels.npy"
pred_file = "/masvol/heartsmart/unet_model/baseline/results/roi/combined_1_3_0_256_roi_aug_dice_predictions.npy"
plot_learning_history(history_file)
show_performance_statistics(label_file, pred_file)
find_outliers(label_file, pred_file)
display_images_labels_predictions (image_file, label_file, pred_file, num_images = 4, random_images = True)
print('-'*30)
print('-'*30)
zcontour = [47, 68, 81, 82, 141, 155, 173, 202, 213]
display_images_labels_predictions (image_file, label_file, pred_file, image_list = zcontour)
# Out:
# ------------------------------
# Model Parameters
# tr_size  :  9748
# tr_nGPUs  :  4
# tr_loss_fn  :  dice_loss
# tr_dropout  :  False
# tr_model_name  :  combined_1_3_0_256_roi_aug_dice
# tr_epoch  :  80
# tr_optimizer  :  Adam
# tr_lrrate  :  2e-05
# tr_batchsize  :  32
# ------------------------------
# Evaluation on Test set
# eval_binary_accuracy  :  0.9741999873408564
# eval_loss  :  0.9995030111736721
# eval_dice_coeff  :  0.0004969941238717486
# ------------------------------
# Values at first and last epoch
# ------------------------------
# val_dice_coeff  :  0.6495744925890213 , 0.9491593939830095
# binary_accuracy  :  0.8719845048034152 , 0.9976367798485063
# val_loss  :  0.35042550741097866 , 0.05084060601699047
# val_binary_accuracy  :  0.9774294963249793 , 0.9959855532646179
# dice_coeff  :  0.4431132716104048 , 0.9752181048544898
# loss  :  0.5568867292609634 , 0.024781895145510185
# ------------------------------
# ------------------------------
# ------------------------------
# Loss and Accuracy
# ------------------------------
# log_loss :  0.04804624791827728   Accuracy:  0.9530897076433116
# weighted log_loss :  0.15055233006178875   Weighted_accuracy:  0.8602327127985333
# ------------------------------
# Model Performance
# ------------------------------
# precision : 0.9456361534492556
# recall : 0.9512546592556579
# f1 score : 0.9484370854709159
#
# true_p = 434360, false_p = 24971, true_neg = 17213131, false_neg = 22258
# confuion matrix
# [[17213131    24971]
#  [   22258   434360]]
# ------------------------------
# ------------------------------
# Number of Samples : 270, image size : 256 x 256
# ------------------------------
# Outliers
# ------------------------------
# Sample Index of labels with zero contours [38, 53, 70, 87, 145, 151]
# Sample Index of predictions with zero contours [2, 10, 13, 53, 70, 87, 116, 118, 145]
# max-sigmoid values with zero contours [1.729781e-05, 1.785021e-05, 1.729781e-05, 1.7729875e-05, 1.729781e-05, 1.729781e-05, 1.731547e-05, 0.0038629046, 1.7313687e-05]
# (270,)
# ------------------------------
# Statistics on missed predictions of contour pixels (white pixels)
# ------------------------------
# Sample Index where missed predictions <.05% 5 [53, 70, 87, 97, 145]
# Sample Index where missed predictions >25% 32 [2, 5, 6, 10, 13, 18, 21, 30, 37, 38, 50, 55, 72, 73, 113, 116, 118, 151, 152, 177, 184, 188, 191, 202, 203, 207, 214, 227, 230, 250, 266, 269]
# Sample Index where missed predictions >50% 23 [2, 5, 6, 10, 13, 18, 21, 30, 37, 38, 55, 72, 113, 116, 118, 151, 177, 184, 188, 202, 203, 207, 230]
# Sample Index where missed predictions >= 100% 14 [2, 5, 10, 13, 30, 38, 113, 116, 118, 151, 177, 184, 188, 203]
# ------------------------------
# ------------------------------
# samples, max, min  270 1.0 0.0
# ------------------------------
# ------------------------------
# samples, max, min  270 1.0 0.0

# %% [markdown]
# ## Analysis on training with 256x256  combined data set (ACDC + Sunnybrook)
# ### Below are the results of 4 tests
# 1. Training with combined dataset
# 2. Training with combined dataset + Augmentation
# 3. Training with combined dataset (no augmentation),  using Unet with dropout layers
# 4. Training with combined dataset + Augmentation,  using Unet with dropout layers

# %%
## Analysis on training with 256x256  combined data set (ACDC + Sunnybrook) (No labels with zero contours)

### data set prefix combined_1_3_256 

### Below are the results of 4 tests
# 1. Training with combined dataset
# 2. Training with combined dataset + Augmentation
# 3. Training with combined dataset (no augmentation),  using Unet with dropout layers
# 4. Training with combined dataset + Augmentation,  using Unet with dropout layers

# %%
# zcontour = [50, 53, 72, 73, 116, 118, 145, 188]
# display_images_labels_predictions (image_file, label_file, pred_file, image_list = zcontour)

# %% [markdown]
# ## reg for just dice, regular 256

# %%
weights_file = "/masvol/heartsmart/unet_model/baseline/results/roi/combined_1_3_0_256_roi_dice.hdf5"
history_file = '/masvol/heartsmart/unet_model/baseline/results/roi/combined_1_3_0_256_roi_dice_learning_history.json'
image_file = "/masvol/heartsmart/unet_model/baseline/data/combined_1_3_0_256_test_images_ROI_norm.npy"
label_file = "/masvol/heartsmart/unet_model/baseline/data/combined_1_3_0_256_test_labels.npy"
pred_file = "/masvol/heartsmart/unet_model/baseline/results/roi/combined_1_3_0_256_roi_dice_predictions.npy"
plot_learning_history(history_file)
show_performance_statistics(label_file, pred_file)
find_outliers(label_file, pred_file)
display_images_labels_predictions (image_file, label_file, pred_file, num_images = 4, random_images = True)
print('-'*30)
print('-'*30)
zcontour = [47, 68, 81, 82, 141, 155, 173, 202, 213]
display_images_labels_predictions (image_file, label_file, pred_file, image_list = zcontour)
# Out:
# ------------------------------
# Model Parameters
# tr_size  :  2437
# tr_loss_fn  :  dice_loss
# tr_nGPUs  :  4
# tr_dropout  :  False
# tr_model_name  :  combined_1_3_0_256_roi_dice
# tr_epoch  :  80
# tr_optimizer  :  Adam
# tr_lrrate  :  2e-05
# tr_batchsize  :  32
# ------------------------------
# Evaluation on Test set
# eval_binary_accuracy  :  0.9743584526909722
# eval_loss  :  0.9911639460810908
# eval_dice_coeff  :  0.008836058302053803
# ------------------------------
# Values at first and last epoch
# ------------------------------
# loss  :  0.8989513553736331 , 0.03118211263384557
# binary_accuracy  :  0.58356016699995 , 0.9986026814621249
# val_loss  :  0.720882909219773 , 0.07322290295460185
# val_binary_accuracy  :  0.9343040653916656 , 0.9955735753794186
# dice_coeff  :  0.10104864097944341 , 0.9688178873661544
# val_dice_coeff  :  0.27911709664297885 , 0.9267770970453981
# ------------------------------
# ------------------------------
# ------------------------------
# Loss and Accuracy
# ------------------------------
# log_loss :  0.0407232545914816   Accuracy:  0.9600947950115719
# weighted log_loss :  0.1266077751430116   Weighted_accuracy:  0.8810791859909775
# ------------------------------
# Model Performance
# ------------------------------
# precision : 0.9373422787091018
# recall : 0.9387299668431818
# f1 score : 0.9380356095554058
#
# true_p = 428641, false_p = 28653, true_neg = 17209449, false_neg = 27977
# confuion matrix
# [[17209449    28653]
#  [   27977   428641]]
# ------------------------------
# ------------------------------
# Number of Samples : 270, image size : 256 x 256
# ------------------------------
# Outliers
# ------------------------------
# Sample Index of labels with zero contours [38, 53, 70, 87, 145, 151]
# Sample Index of predictions with zero contours [2, 10, 13, 70, 72, 73, 87, 116, 118, 145, 188]
# max-sigmoid values with zero contours [0.0004099032, 0.17634903, 0.0019545646, 5.560382e-05, 3.6931335e-05, 0.034170285, 0.0155358, 3.8156486e-05, 3.629124e-05, 0.0007181424, 0.046805758]
# (270,)
# ------------------------------
# Statistics on missed predictions of contour pixels (white pixels)
# ------------------------------
# Sample Index where missed predictions <.05% 7 [56, 70, 77, 87, 145, 155, 163]
# Sample Index where missed predictions >25% 49 [2, 5, 6, 10, 13, 18, 21, 23, 30, 37, 38, 50, 53, 55, 72, 73, 86, 88, 98, 113, 116, 118, 131, 151, 164, 166, 174, 177, 180, 184, 188, 191, 194, 201, 202, 203, 207, 212, 214, 223, 226, 227, 228, 230, 231, 239, 250, 266, 269]
# Sample Index where missed predictions >50% 32 [2, 5, 6, 10, 13, 18, 30, 38, 50, 53, 72, 73, 98, 113, 116, 118, 151, 174, 177, 184, 188, 191, 194, 202, 203, 207, 212, 214, 228, 230, 231, 269]
# Sample Index where missed predictions >= 100% 17 [2, 5, 10, 13, 38, 53, 72, 73, 113, 116, 118, 151, 184, 203, 212, 230, 231]
# ------------------------------
# ------------------------------
# samples, max, min  270 1.0 0.0
# ------------------------------
# ------------------------------
# samples, max, min  270 1.0 0.0

# %%
# everything below this point hasn't been filled out to the correct paths

# %% [markdown]
# ## 256 drop

# %%
image_file = "/masvol/output/unet_training/combined_1_1_256_test_images.npy"
label_file = "/masvol/output/unet_training/combined_1_1_256_test_labels.npy"

weights_file = "/masvol/heartsmart/unet_model/data/combined_1_1_256_dice_drop_32B.hdf5"
history_file = '/masvol/heartsmart/unet_model/data/combined_1_1_256_dice_drop_32B_learning_history.json'
image_file = "/masvol/output/unet_training/combined_1_1_256_test_images.npy"
label_file = "/masvol/output/unet_training/combined_1_1_256_test_labels.npy"
pred_file = "/masvol/heartsmart/unet_model/data/combined_1_1_256_dice_drop_32B_predictions.npy"
plot_learning_history(history_file)
show_performance_statistics(label_file, pred_file)
find_outliers(label_file, pred_file)
display_images_labels_predictions (image_file, label_file, pred_file, num_images = 4, random_images = True)
print('-'*30)
print('-'*30)
zcontour = [47, 68, 81, 82, 141, 155, 173, 202, 213]
display_images_labels_predictions (image_file, label_file, pred_file, image_list = zcontour)

# %% [markdown]
# ## 256 aug drop

# %%
weights_file = "/masvol/heartsmart/unet_model/data/combined_1_1_256_dice_aug_drop_32B.hdf5"
history_file = '/masvol/heartsmart/unet_model/data/combined_1_1_256_dice_aug_drop_32B_learning_history.json'
#image_file = "/masvol/heartsmart/unet_model/baseline/data/combined_1_3_256_test_images.npy"
#label_file = "/masvol/heartsmart/unet_model/baseline/data/combined_1_3_256_test_labels.npy"
pred_file = "/masvol/heartsmart/unet_model/data/combined_1_1_256_dice_aug_drop_32B_predictions.npy"
plot_learning_history(history_file)
show_performance_statistics(label_file, pred_file)
find_outliers(label_file, pred_file)
display_images_labels_predictions (image_file, label_file, pred_file, num_images = 4, random_images = True)
print('-'*30)
print('-'*30)
zcontour = [47, 68, 81, 82, 141, 155, 173, 202, 213]
display_images_labels_predictions (image_file, label_file, pred_file, image_list = zcontour)

# %% [markdown]
# ## Analysis on training with 176x176  combined data set (ACDC + Sunnybrook)  ( no Labels with zero contours)
# ### (data set prefix combined_1_3_176)
# ### Below are the results of 4 tests
# 1. Training with combined dataset
# 2. Training with combined dataset + Augmentation
# 3. Training with combined dataset (no augmentation),  using Unet with dropout layers
# 4. Training with combined dataset + Augmentation,  using Unet with dropout layers

# %% [markdown]
# ## reg 176

# %%
weights_file = "/masvol/heartsmart/unet_model/data/combined_1_1_176_dice_reg_32B.hdf5"
history_file = '/masvol/heartsmart/unet_model/data/combined_1_1_176_dice_reg_32B_learning_history.json'
image_file = "/masvol/output/unet_training/combined_1_1_176_test_images.npy"
label_file = "/masvol/output/unet_training/combined_1_1_176_test_labels.npy"
pred_file = "/masvol/heartsmart/unet_model/data/combined_1_1_176_dice_reg_32B_predictions.npy"
plot_learning_history(history_file)
show_performance_statistics(label_file, pred_file)
find_outliers(label_file, pred_file)
display_images_labels_predictions (image_file, label_file, pred_file, num_images = 4, random_images = True)
print('-'*30)
print('-'*30)
zcontour = [47, 68, 81, 82, 141, 155, 173, 202, 213]
display_images_labels_predictions (image_file, label_file, pred_file, image_list = zcontour)

# %% [markdown]
# ## aug 176

# %%
weights_file = "/masvol/heartsmart/unet_model/data/combined_1_1_176_dice_aug_32B.hdf5"
history_file = '/masvol/heartsmart/unet_model/data/combined_1_1_176_dice_aug_32B_learning_history.json'
#image_file = "/masvol/heartsmart/unet_model/baseline/data/combined_1_3_176_test_images.npy"
#label_file = "/masvol/heartsmart/unet_model/baseline/data/combined_1_3_176_test_labels.npy"
pred_file = "/masvol/heartsmart/unet_model/data/combined_1_1_176_dice_aug_32B_predictions.npy"
plot_learning_history(history_file)
show_performance_statistics(label_file, pred_file)
find_outliers(label_file, pred_file)
display_images_labels_predictions (image_file, label_file, pred_file, num_images = 4, random_images = True)
print('-'*30)
print('-'*30)
zcontour = [47, 68, 81, 82, 141, 155, 173, 202, 213]
display_images_labels_predictions (image_file, label_file, pred_file, image_list = zcontour)

# %% [markdown]
# ## drop 176

# %%
weights_file = "/masvol/heartsmart/unet_model/data/combined_1_1_176_dice_drop_32B.hdf5"
history_file = '/masvol/heartsmart/unet_model/data/combined_1_1_176_dice_drop_32B_learning_history.json'
#image_file = "/masvol/heartsmart/unet_model/baseline/data/combined_1_3_176_test_images.npy"
#label_file = "/masvol/heartsmart/unet_model/baseline/data/combined_1_3_176_test_labels.npy"
pred_file = "/masvol/heartsmart/unet_model/data/combined_1_1_176_dice_drop_32B_predictions.npy"
plot_learning_history(history_file)
show_performance_statistics(label_file, pred_file)
find_outliers(label_file, pred_file)
display_images_labels_predictions (image_file, label_file, pred_file, num_images = 4, random_images = True)
print('-'*30)
print('-'*30)
zcontour = [47, 68, 81, 82, 141, 155, 173, 202, 213]
display_images_labels_predictions (image_file, label_file, pred_file, image_list = zcontour)

# %% [markdown]
# ## aug drop 176

# %%
weights_file = "/masvol/heartsmart/unet_model/data/combined_1_1_176_dice_aug_drop_32B.hdf5"
history_file = '/masvol/heartsmart/unet_model/data/combined_1_1_176_dice_aug_drop_32B_learning_history.json'
#image_file = "/masvol/heartsmart/unet_model/baseline/data/combined_1_3_176_test_images.npy"
#label_file = "/masvol/heartsmart/unet_model/baseline/data/combined_1_3_176_test_labels.npy"
pred_file = "/masvol/heartsmart/unet_model/data/combined_1_1_176_dice_aug_drop_32B_predictions.npy"
plot_learning_history(history_file)
show_performance_statistics(label_file, pred_file)
find_outliers(label_file, pred_file)
display_images_labels_predictions (image_file, label_file, pred_file, num_images = 4, random_images = True)
print('-'*30)
print('-'*30)
zcontour = [47, 68, 81, 82, 141, 155, 173, 202, 213]
display_images_labels_predictions (image_file, label_file, pred_file, image_list = zcontour)

# %%
## Analysis on training with 176x176  combined data set (ACDC + Sunnybrook) + Labels with Zero Contours  
### (data set prefix combined_1_3_0_176)
### Below are the results of 4 tests
# 1. Training with combined dataset
# 2. Training with combined dataset + Augmentation
# 3. Training with combined dataset (no augmentation),  using Unet with dropout layers
# 4. Training with combined dataset + Augmentation,  using Unet with dropout layers
