# %%
import pandas as pd
import pprint

# %%
pp = pprint.PrettyPrinter(indent=4)

# %%
import MySQLdb

db = {'host':'localhost', 'user':'root', 'password':'mastf','db':'mastf','port':3306}

conn = MySQLdb.connect(host=db['host'],user=db['user'],password=db['password'],db=db['db'],port=db['port'])
curs = conn.cursor()

# %%
sql = "describe volume_pred"
curs.execute(sql)
results = curs.fetchall()
pp.pprint (results)
# Out:
# (   ('model_id', 'int(11) unsigned', 'NO', 'PRI', None, 'auto_increment'),
#     ('systole_rmse', 'float unsigned', 'YES', '', None, ''),
#     ('diastole_rmse', 'float', 'YES', '', None, ''),
#     ('ef_rmse', 'float', 'YES', '', None, ''),
#     ('tr_model_name', 'varchar(100)', 'YES', 'UNI', None, ''))

# %%
df = pd.read_csv('/masvol/heartsmart/unet_model/Volume_0520.csv')

# %%
df['tr_model_name'] = df['Unnamed: 0']

# %%
df.drop('Unnamed: 0', inplace=True, axis=1)

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+mysqldb://root:mastf@localhost:3306/mastf')

# %%
df.to_sql('volume_pred',con=engine,if_exists='replace')

# %%
conn2 = engine.connect()

# %%
result = conn2.execute("select * from volume_pred")

# %%
for r in result:
    pp.pprint(r)
# Out:
# (0, 15.47, 19.55, 8, '1combined_1_1_176_dice_aug_32B')
# (1, 15.22, 20.09, 8, '1combined_1_1_176_dice_aug_drop_32B')
# (2, 31.52, 38.9, 10, '1combined_1_1_176_dice_drop_32B')
# (3, 27.7, 33.85, 10, '1combined_1_1_176_dice_reg_32B')
# (4, 17.95, 21.34, 8, '1combined_2_1_176_aug_dice')
# (5, 16.34, 19.14, 9, '1combined_2_1_176_aug_drop_dice')
# (6, 20.6, 24.49, 10, '1combined_2_1_176_dice')
# (7, 29.9, 34.77, 9, '1combined_2_1_176_drop_dice')
# (8, 2161.01, 2202.08, 54, '2combined_1_2_176_dice_128b')
# (9, 68.5, 158.64, 59, '2combined_1_2_176_dice_16b')
# (10, 20.12, 27.02, 9, '2combined_1_2_176_dice_32b')
# (11, 19.64, 26.16, 9, '2combined_1_2_176_dice_64b')
# (12, 20.64, 26.1, 9, '2combined_1_2_176_dice_8b')
# (13, 16.53, 21.61, 8, '2combined_1_2_176_dice_aug_32B')
# (14, 18.49, 25.2, 9, '2combined_1_2_176_dice_aug_drop_32B')
# (15, 30.94, 41.34, 10, '2combined_1_2_176_dice_drop_32B')
# (16, 15.55, 22.24, 8, '2combined_2_2_176_aug_dice')
# ...

# %%
vol = pd.read_sql("select * from volume_pred", con=conn)

# %%
vol
# Out:
#     index  Systole RMSE  Diastole RMSE  EF RMSE  \
# 0       0         15.47          19.55        8
# 1       1         15.22          20.09        8
# 2       2         31.52          38.90       10
# 3       3         27.70          33.85       10
# 4       4         17.95          21.34        8
# 5       5         16.34          19.14        9
# 6       6         20.60          24.49       10
# 7       7         29.90          34.77        9
# 8       8       2161.01        2202.08       54
# 9       9         68.50         158.64       59
# 10     10         20.12          27.02        9
# 11     11         19.64          26.16        9
# 12     12         20.64          26.10        9
# 13     13         16.53          21.61        8
# 14     14         18.49          25.20        9
# 15     15         30.94          41.34       10
# 16     16         15.55          22.24        8
# 17     17         17.70          23.09        9
# ...
